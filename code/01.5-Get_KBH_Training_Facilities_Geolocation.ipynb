# %%
import googlemaps
import pandas as pd
from geopy.distance import geodesic
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
gmaps = googlemaps.Client(key=os.getenv('api_key'))

# %%
def get_lat_lng(address):
    try:
        geocode_result = gmaps.geocode(address)

        if geocode_result and len(geocode_result) > 0:
            location = geocode_result[0]['geometry']['location']
            return location['lat'], location['lng']
        else:
            return None, None
        
    except Exception as e:
        print(f"An error occurred while geocoding: {e}")
        return None, None

# %%
import csv

file_path = '../data/raw_data/kbh_facilities.csv'
output_file_path = '../data/raw_data/kbh_facilities_with_coordinates.csv'

modified_rows = []

with open(file_path, mode='r', encoding='utf-16') as file: 
    csv_reader = csv.reader(file)
    headers = next(csv_reader)
    headers.extend(['lat', 'lng'])
    modified_rows.append(headers)
    
    for row in csv_reader:
        if not row:  
            continue
        
        address = row[-1].strip() 
        location = row[-2].strip()  
        
        #look first if we can find lat and lng for the address
        lat_lng = get_lat_lng(address)
        
        # if there is no address or we can find the coordiantes using address we use the location
        if not lat_lng or not all(lat_lng):
            lat_lng = get_lat_lng(location)
        
        # if none of location and address works we just return none for both of them
        if not lat_lng or not all(lat_lng):
            lat_lng = (None, None)
        
        row.extend(lat_lng)
        modified_rows.append(row)

with open(output_file_path, mode='w', newline='', encoding='utf-16') as file:
    csv_writer = csv.writer(file)
    csv_writer.writerows(modified_rows)
    
# for some places the google maps looks like it doesnt recognize neither the address and location thats why we get HTTP Error: 400
# Out:
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# An error occurred while geocoding: HTTP Error: 400
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\Veronii\Desktop\data-wild-west\code\01.5-Get_KBH_Training_Facilities_Geolocation.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Veronii/Desktop/data-wild-west/code/01.5-Get_KBH_Training_Facilities_Geolocation.ipynb#X10sZmlsZQ%3D%3D?line=31'>32</a>         row.extend(lat_lng)
#      <a href='vscode-notebook-cell:/c%3A/Users/Veronii/Desktop/data-wild-west/code/01.5-Get_KBH_Training_Facilities_Geolocation.ipynb#X10sZmlsZQ%3D%3D?line=32'>33</a>         modified_rows.append(row)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Veronii/Desktop/data-wild-west/code/01.5-Get_KBH_Training_Facilities_Geolocation.ipynb#X10sZmlsZQ%3D%3D?line=34'>35</a> with open(output_file_path, mode='w', newline='', encoding='utf-16') as file:
#      <a href='vscode-notebook-cell:/c%3A/Users/Veronii/Desktop/data-wild-west/code/01.5-Get_KBH_Training_Facilities_Geolocation.ipynb#X10sZmlsZQ%3D%3D?line=35'>36</a>     csv_writer = csv.writer(file)
#      <a href='vscode-notebook-cell:/c%3A/Users/Veronii/Desktop/data-wild-west/code/01.5-Get_KBH_Training_Facilities_Geolocation.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>     csv_writer.writerows(modified_rows)
#
# File c:\Users\Veronii\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: '../data/raw_data/kbh_facilities_with_coordinates.csv'

# %%
df = pd.read_csv('../data/raw_data/kbh_facilities_with_coordinates.csv', encoding='utf-16')
df
# Out:
#      Unnamed: 0                     type  \
# 0             0  Styrke- og grundtræning
# 1             1        Træningspavillion
# 2             2                 Kondisti
# 3             3             Nærgymnastik
# 4             4    Stavgang for seniorer
# ..          ...                      ...
# 605         605               Mix Volley
# 606         606         Motionsgymnastik
# 607         607  Cykeltur - roligt tempo
# 608         608      Varmtvandsgymnastik
# 609         609               Bordtennis
#
#                                                website  \
# 0                             http://www.sosmotion.dk/
# 1                                                  NaN
# 2                                                  NaN
# 3    https://lofskolen.dk/kurser/motion-og-sundhed/...
# 4             https://kbhkg.klub-modul.dk/default.aspx
# ..                                                 ...
# 605                      https://ifk98.dk/default.aspx
# 606                      https://ifk98.dk/default.aspx
# 607                      https://ifk98.dk/default.aspx
# 608                      https://ifk98.dk/default.aspx
# 609                      https://ifk98.dk/default.aspx
#
#                          location  \
# 0                      SOS Motion
# 1                             NaN
# 2                     Valbyparken
# 3                       LOFskolen
# 4    Københavns Gymnastikforening
# ..                            ...
# 605     Idrætsforeningen Kæmperne
# 606     Idrætsforeningen Kæmperne
# 607     Idrætsforeningen Kæmperne
# 608     Idrætsforeningen Kæmperne
# 609     Idrætsforeningen Kæmperne
#
#                                                address        lat        lng
# 0    Sundhedshus Østerbro, Randersgade 60, 4 sal, 2...  55.707451  12.580255
# 1                            Kvægtorvsgade, 1710 KBH V  55.669719  12.563130
# 2                            Tudsemindevej, 2450 Valby  55.643635  12.525831
# 3                   Østerbrogade 240, 2100 København Ø  55.713762  12.578719
# 4                     Ole Suhrs Gade 3, 1354 København  55.688828  12.572720
# ..                                                 ...        ...        ...
# 605               Øster Farimagsgade Skole, Multisalen  55.692734  12.577780
# 606                                                NaN  55.700596  12.515967
# 607                                                NaN  55.700596  12.515967
# 608                                                NaN  55.700596  12.515967
# 609                                            Remisen  55.698689  12.576742
#
# [610 rows x 7 columns]
